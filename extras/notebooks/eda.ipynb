# %% [markdown]
# # Exploratory Data Analysis
#
# Optional notebook for data exploration. Production training uses `main.py`.

# %%
import matplotlib.pyplot as plt
import pandas as pd

from data.cleaning import clean
from data.loader import load_raw

# %%
df = clean(load_raw("../assets/data.csv"), granularity="store_sku")
df.head()

# %%
df.describe()

# %%
sample = df[(df["store_id"] == df["store_id"].iloc[0]) & (df["sku_id"] == df["sku_id"].iloc[0])]
sample.plot(x="week_dt", y="units_sold", figsize=(12, 4), title="Sample series")
plt.show()

# %%
df.groupby("store_id")["units_sold"].sum().sort_values(ascending=False).head(10)
